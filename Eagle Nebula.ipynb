# %%
## Viewing the Eagle Nebula (also known as the Pillars of Creation or PoC) using its .FITS file.

# %%
# Importing necessary libaries/modules
import numpy as np
import matplotlib.pyplot as mp
from astropy.io import fits

# %%
# To open the .fits file and make it ready for use
POC=fits.open('F:/Uni/Sem 1/Club Work/AstroClub/Observational/Eagle Nebula/502nmos.fits')

# %%
POC    #This and following cells are just checks
# Out:
# [<astropy.io.fits.hdu.image.PrimaryHDU object at 0x00000253F6444040>, <astropy.io.fits.hdu.table.TableHDU object at 0x00000253F64E7B50>]

# %%
POC.info()
# Out:
# Filename: F:/Uni/Sem 1/Club Work/AstroClub/Observational/Eagle Nebula/502nmos.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     290   (1600, 1600)   float32
#   1  502nmos_cvt.tab    1 TableHDU       353   1R x 49C   [D25.17, D25.17, E15.7, E15.7, E15.7, E15.7, E15.7, E15.7, E15.7, E15.7, A1, E15.7, I12, I12, D25.17, D25.17, A8, A8, I12, E15.7, E15.7, E15.7, E15.7, E15.7, E15.7, I12, I12, I12, I12, I12, I12, I12, I12, A48, E15.7, E15.7, E15.7, E15.7, E15.7, E15.7, E15.7, E15.7, E15.7, E15.7, E15.7, E15.7, E15.7, E15.7, E15.7]

# %%
POC[0]

# %%
data = POC[0].data
data.shape
# Out:
# (1600, 1600)

# %%
# To check the colourbar of the fits file in normal mapping
mp.imshow(data, cmap="gray")
mp.colorbar()

# %%
# Since normal mapping did not give any clear picture, we switch to lognormal distribution, for which the results are much more profound
from matplotlib.colors import LogNorm

mp.imshow(data, cmap='gray', norm=LogNorm())
cbar = mp.colorbar(ticks=[5.e3,1.e4,2.e4])
cbar.ax.set_yticklabels(['5,000','10,000','20,000'])
# Out:
# [Text(1, 5000.0, '5,000'),
#  Text(1, 10000.0, '10,000'),
#  Text(1, 20000.0, '20,000')]

# %%
from astropy.visualization import make_lupton_rgb

# %%
POC502=fits.open('F:/Uni/Sem 1/Club Work/AstroClub/Observational/Eagle Nebula/502nmos.fits')
POC656=fits.open('F:/Uni/Sem 1/Club Work/AstroClub/Observational/Eagle Nebula/656nmos.fits')
POC673=fits.open('F:/Uni/Sem 1/Club Work/AstroClub/Observational/Eagle Nebula/673nmos.fits')

# %%
b=POC502[0].data
o=POC656[0].data
r=POC673[0].data

# %%
rgb_default = make_lupton_rgb(r,b/1.5,b,stretch=2.5,Q=10)

mp.imshow(rgb_default, origin='lower')
#plt.savefig('PoC.jpg')

# %%
## make_lupton_rgb is a function taken from the AstroPy library whose purpose is to generate a plot of the rgb image by using 
## three numpy nd arrays, each containing the colour coding for red, green, and blue respectively (the three filters).
## Addtionally, these ndarrays can be scaled up or down to vary the intensity of the respective colour codes.
## Stretch parameter of this functions varies the brightness of the generated image
## Important to note is that make_lupton_rgb just generates the image, but not display. For displaying it, we use imshow().
## Also present as a comment is a line to save the final image as a .jpg file on the system. We can alter the path and save
## the file at any location that we want to, for which I have kept it as a comment line.
